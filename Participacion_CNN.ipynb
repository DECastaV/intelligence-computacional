# %% [markdown]
# # ASL Recognition with CNNs
#
# This notebook implements a Convolutional Neural Network (CNN) for recognizing American Sign Language (ASL) gestures. We will compare the performance of a Fully Connected Neural Network (FCNN) with that of a CNN on the ASL dataset.
#
# For more information on the ASL alphabet, you can refer to this site: https://www.asl.gs/

# %%
import random

import torch.nn as nn
import pandas as pd
import torch
from torch.optim import Adam
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
# Out:
# False

# %%
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False

data_base_path = "" if IN_COLAB else "../data/asl_data/"

# %% [markdown]
# ### Load data
#
# The data for the ASL dataset is stored in CSV files. It is already split into training, validation, and test sets. Each row in the CSV files contains pixel values for a 28x28 image (flattened into a single row) and a label indicating the ASL gesture.
#
# The labels are integers from 0 to 23, corresponding to the letters A-Z (J and Z are excluded because they require movement).
#
# The images are grayscale, so each pixel value ranges from 0 to 255.

# %%
train_df = pd.read_csv(data_base_path + "train.csv")
val_df = pd.read_csv(data_base_path + "val.csv")
test_df = pd.read_csv(data_base_path + "test.csv")

# %%
def label_to_letter(lbl):
    letter_code = ord('A') + int(lbl)
    return chr(letter_code) if letter_code < ord('J') else chr(letter_code + 1)

def show(img, lbl):
    i = img.reshape(28,28)
    plt.figure(figsize=(5,5))
    plt.title(label_to_letter(lbl), fontdict={'fontsize': 30})
    plt.axis('off')
    plt.imshow(i, cmap='gray')

# %%
rnd_idx = random.choice(train_df.index)
image = train_df.iloc[rnd_idx].drop('label').values
label = train_df.iloc[rnd_idx]['label']
show(image, label)

# %% [markdown]
# ## Preparing dataset
#
# Let's start by creating the custom Dataset class for our ASL data. This class will take a DataFrame as input and will return the image and label for each sample. We will also normalize the pixel values to be between 0 and 1. The images will be reshaped as a 28x28 tensor with a single channel (grayscale).

# %%
IMG_HEIGHT = 28
IMG_WIDTH = 28
IMG_CHANNELS = 1

class AslDataset(Dataset):
    def __init__(self, base_df):
        x_df = base_df.copy()
        y_df = x_df.pop('label')
        x_df = x_df.values / 255
        x_df = x_df.reshape(-1, IMG_CHANNELS, IMG_WIDTH, IMG_HEIGHT)
        self.xs = torch.tensor(x_df).float().to(device)
        self.ys = torch.tensor(y_df).long().to(device)

    def __getitem__(self, idx):
        x = self.xs[idx]
        y = self.ys[idx]
        return x, y

    def __len__(self):
        return len(self.xs)

# %%
train_data = AslDataset(train_df)
val_data = AslDataset(val_df)
test_data = AslDataset(test_df)

# %%
batch_size = 32

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Training functions
#
# Now we can define our training functions. Since we will use accuracy to evaluate our model, we will create a function to calculate accuracy as well.

# %%
def get_batch_accuracy(output, y, N):
    pred = output.argmax(dim=1, keepdim=True)
    correct = pred.eq(y.view_as(pred)).sum().item()
    return correct / N

# %% [markdown]
# Our train function performs the full training loop. For each epoch, it computes the training loss and accuracy, and then evaluates the model on the validation set. It returns the history of training and validation losses and accuracies for plotting later.

# %%
def train(_model, _train_loader, _val_loader, _criterion, _optimizer, _num_epochs):
    res = {
        'train_loss': [],
        'train_acc': [],
        'val_loss': [],
        'val_acc': [],
    }
    iterator = tqdm(range(epochs), desc="Training", unit="epoch")

    # Tensores para graficar learning curve
    epoch_train_losses = torch.zeros(_num_epochs)
    epoch_val_losses = torch.zeros(_num_epochs)

    for _ in iterator:
        _model.train()
        train_loss = 0.0
        train_acc = 0.0
        for X_batch, y_batch in _train_loader:
            _optimizer.zero_grad()
            outputs = _model(X_batch)
            loss = _criterion(outputs, y_batch)
            loss.backward()
            _optimizer.step()
            train_loss += loss.item() * X_batch.size(0)
            train_acc += get_batch_accuracy(outputs, y_batch, len(_train_loader.dataset))

        epoch_train_loss = train_loss / len(_train_loader.dataset)
        epoch_train_losses[_] = epoch_train_loss

        _model.eval()
        val_loss = 0.0
        val_acc = 0.0
        with torch.no_grad():
            for X_val, y_val in _val_loader:
                val_outputs = _model(X_val)
                val_loss += _criterion(val_outputs, y_val).item() * X_val.size(0)
                val_acc += get_batch_accuracy(val_outputs, y_val, len(_val_loader.dataset))

        epoch_val_loss = val_loss / len(_val_loader.dataset)
        epoch_val_losses[_] = epoch_val_loss

        iterator.set_postfix(
            train_loss=f"{epoch_train_loss:.4f}",
            train_acc=f"{train_acc:.4f}",
            val_loss=f"{epoch_val_loss:.4f}",
            val_acc=f"{val_acc:.4f}",
        )

        res['train_loss'].append(epoch_train_loss)
        res['train_acc'].append(train_acc)
        res['val_loss'].append(epoch_val_loss)
        res['val_acc'].append(val_acc)

    return res, epoch_train_losses, epoch_val_losses

# %% [markdown]
# This test function will evaluate the model on the test set after training is complete. It will calculate the average loss and accuracy across the entire test set.

# %%
def test(_model, _test_loader, _loss_function):
    _model.eval()
    test_loss = 0.0
    test_acc = 0.0
    with torch.no_grad():
        for x, y in _test_loader:
            output = _model(x)
            test_loss += _loss_function(output, y).item() * x.size(0)
            test_acc += get_batch_accuracy(output, y, len(_test_loader.dataset))

    return (test_loss / len(_test_loader.dataset)), test_acc

# %% [markdown]
# # Función de learning curves

# %%
def plot_learning_curves(_train_losses, _val_losses, epochs):

  epochs = range(1, epochs + 1)

  plt.plot(epochs, _train_losses, label="Train Loss")
  plt.plot(epochs, _val_losses, label="Validation Loss")
  plt.ylim(top=2.25)
  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Learning Curves")
  plt.legend()
  plt.show()
pass

# %% [markdown]
# ## Training the models

# %% [markdown]
# ### Baseline model - fully connected network
#
# Before we implement the CNN, let's train a simple fully connected neural network (FCNN) as a baseline. This will help us understand the performance improvement that the CNN architecture provides for image data.

# %%
model_fcnn = nn.Sequential(
    nn.Flatten(),
    nn.Linear(IMG_HEIGHT * IMG_WIDTH, 512),
    nn.ReLU(),
    nn.Dropout(.3),

    nn.Linear(512, 512),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_fcnn = model_fcnn.to(device)

# %%
epochs = 20
loss_function_m1 = nn.CrossEntropyLoss()
optimizer_m1 = Adam(model_fcnn.parameters())

fcnn_res, train_losses_m1, val_losses_m1 = train(model_fcnn, train_loader, val_loader, loss_function_m1, optimizer_m1, epochs)
# Out:
# Training: 100%|██████████| 20/20 [03:36<00:00, 10.83s/epoch, train_acc=0.8655, train_loss=0.3889, val_acc=0.7412, val_loss=0.8052]

# %%
fcnn_test_loss, fcnn_test_acc = test(model_fcnn, test_loader, loss_function_m1)

# %% [markdown]
# ### CNN model
#
# Now let's implement a simple CNN architecture. We will use three convolutional layers followed by max pooling, and then a couple of fully connected layers before the output layer.

# %%
model_cnn = nn.Sequential(
    nn.Conv2d(IMG_CHANNELS, 25, 3, stride=1, padding=1),  # 25 x 28 x 28
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 25 x 14 x 14

    nn.Conv2d(25, 50, 3, stride=1, padding=1),  # 50 x 14 x 14
    nn.ReLU(),
    nn.Dropout(.2),
    nn.MaxPool2d(2, stride=2),  # 50 x 7 x 7

    nn.Conv2d(50, 75, 3, stride=1, padding=1),  # 75 x 7 x 7
    nn.ReLU(),
    nn.MaxPool2d(2, stride=2),  # 75 x 3 x 3

    nn.Flatten(),
    nn.Linear(75 * 3 * 3, 512),
    nn.Dropout(.3),
    nn.ReLU(),
    nn.Linear(512, 24)
)

model_cnn = model_cnn.to(device)

# %%
epochs = 20
loss_function_m2 = nn.CrossEntropyLoss()
optimizer_m2 = Adam(model_cnn.parameters())

cnn_res, train_losses_m2, val_losses_m2 = train(model_cnn, train_loader, val_loader, loss_function_m2, optimizer_m2, epochs)
# Out:
# Training: 100%|██████████| 20/20 [15:26<00:00, 46.30s/epoch, train_acc=0.9994, train_loss=0.0017, val_acc=0.9582, val_loss=0.2227]

# %%
cnn_test_loss, cnn_test_acc = test(model_cnn, test_loader, loss_function_m2)

# %% [markdown]
# ## Reflection section

# %% [markdown]
# ### Which model is better at classifying ASL images?

# %% [markdown]
# Respuesta:
#
# El **modelo 1** tiene un train loss de 0.3889 y un val loss de 0.8052; mientras que el **modelo 2** que tiene un train loss de 0.0017 y un val loss de 0.2227. Como se podra apreciar en las graficas siguientes, las lineas de Train y Validation loss se mantienen mas separadas (o sus trayectorias mas erraticas) en la grafica del modelo 1, por lo cual indica que el modelo 2 es mas consistente en clasificar las imagenes dadas.

# %% [markdown]
# ### Which model was _faster_ to train?

# %% [markdown]
# Respuesta:
#
# Como se puede apreciar por los outputs de el entrenamiento de cada modelo, el **modelo 1** obtuvo un promedio de 10.83 segundos por epoca, mientras que el **modelo 2** se tardo un promedio de 46.30 segundos. El **modelo 1** fue sin duda el modelo mas rapidod de entrenar; esto no tuvo impacto cualquiera en su desempeño.

# %% [markdown]
# ### Plot and compare the learning curves of both models. What do you observe about their training and validation performance over epochs?

# %%
# MODELO 1
plot_learning_curves(train_losses_m1, val_losses_m1, epochs)

# %%
# MODELO 2
plot_learning_curves(train_losses_m2, val_losses_m2, epochs)

# %% [markdown]
# Respuesta:
#
# En el **modelo 1**, la curva de Validation Loss es muy impredecible; tiene muchos altos y bajos que no parecen ser regidos por una fuerza externa. El Train Loss tiene una curva que se aplana gentilmente, sugiriendo que fue perdiendo su perdida consistentemente. Esta consistencia no se traspasa al desempeño total del modelo, ya que ambas curvas no se asemejan en lo absoluto.
#
# En el **modelo 2**, la curva de Validation Loss se asemeja a una linea plana, lo cual es mejor que tener una curva erratica. Esto va bien en conjunto con el Train Loss, que empieza alto pero se disminuye casi inmediatamente. Aunque no va junto con Validation Loss a una razon de 1:1, se puede apreciar que ambas curvas tengan la misma forma. Su semejanza en ser lineas planas es un mejor indicio que ambas sean completamente diferentes. Y tampoco hay que pasar por alto los valores reales de la curva, ambos bajos comparados con el *modelo 1*.

# %% [markdown]
# ### How many trainable parameters does each model have?
#
# Remember that each convolutional layer has $K \times (C_{in} \times k_h \times k_w + 1)$ parameters, where $K$ is the number of filters, $C_{in}$ is the number of input channels, $k_h$ and $k_w$ are the kernel height and width, and the +1 accounts for the bias term.
#
# Each fully connected layer has $N_{in} \times N_{out} + N_{out}$ parameters, where $N_{in}$ is the number of input features and $N_{out}$ is the number of output features.

# %% [markdown]
# ## Respuesta:
#
# ### El **modelo 1** tiene 676,888 parametros.
#
# Procedimiento:
#
# **Capa #1**: nn.Linear(IMG_HEIGHT * IMG_WIDTH, 512)
#
# Procedimiento: $(28 * 28 + 1) * 512 = 401,920$
#
# **Capa #2**: nn.Linear(512, 512)
#
# Procedimiento: $(512 + 1) * 512 = 262,656$
#
# **Capa #3**: nn.Linear(512, 24)
#
# Procedimiento: $(512 + 1) * 24 = 12,312$
#
# Suma: $401,920 + 262,656 + 12,312 =$ **$676,888$**
#
# Total para el **modelo 1**: **$676,888$**
#
# ### El **modelo 2** tiene 676,888 parametros.
#
# Procedimiento:
#
# **Capa #1**: nn.Conv2d(IMG_CHANNELS, 25, 3, stride=1, padding=1)
#
# $25 * (1 * 3 * 3 + 1) = 250$
#
# **Capa #2**: nn.Conv2d(25, 50, 3, stride=1, padding=1)
#
# $50 * (25 * 3 * 3 + 1) = 11,300$
#
# **Capa #3**: nn.Conv2d(50, 75, 3, stride=1, padding=1)
#
# $75 * (50 * 3 * 3 + 1) = 33,825$
#
# **Capa #4**: nn.Linear(75 * 3 * 3, 512)
#
# $(75 * 3 * 3 + 1) * 512 = 346,112$
#
# **Capa #5**: nn.Linear(512, 24)
#
# $(512 + 1) * 24 = 12,312$
#
# Suma: $250 + 11,300 + 33,825 + 346,112 + 12,312 =$ **$403,799$**
#
# Total para el **modelo 2**: **$403,799$**

# %% [markdown]
# ### How do the models compare in terms of overfitting? Why do you think that is the case?

# %% [markdown]
# Respuesta:
#
# El **modelo 1** tiene problemas de overfitting, dado en lo disparejo que se encuentra el estado de Train y Validation Loss relativos entre si. Validation Loss se encuentra en "otro mundo" mientras que Train calmamente se ralentiza a un punto minimo.
#
# El **modelo 2** tiene un problema con el Validation Loss, pero como mencionado anteriormente, es bueno que su curva se asemeje a la de Train Loss, indicando que hay una sincronizacion mejor que la del **modelo 1**. Ambos modelos no son perfectos, pero el modelo 2 tiene mejor rendimiento.

# %% [markdown]
# ### Final conclusions and remarks

# %% [markdown]
# Conclusion:
#
# Se me hace interesante que una CNN tenga mejor desempeño que una FCNN. En mi mente, se registra que "Full" esta mas completo, y por ende, ha de tener un mejor desempeño; pero ahora que lo veo, la CNN obviamente obtuvo el mejor resultado. Aunque tomo mas tiempo (con menos parametros) (y entrenado en CPU), se me hizo peculiar que un modelo con menos parametros pudo obtener mejores resultados. Durante este ejercicio, repase mucho las diapositivas de la clase para mejor entender por que esta fue la razon. Me fue util retomar conceptos de la clase. En fin, no es por decir que CNN sea lo mejor de lo mejor, estoy seguro que en otros casos FCNN sea una mejor opcion. Pero en este caso, parece que no fue asi.
